# %%
from scipy.misc import  imread
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-e21eb4be122a> in <module>
# ----> 1 from scipy.misc import  imread
#
# ImportError: cannot import name 'imread' from 'scipy.misc' (/Users/sunyinzheng/anaconda3/lib/python3.7/site-packages/scipy/misc/__init__.py)

# %%
pip install scipy.misc
# Out:
# ...
# ^C
# ERROR: Operation cancelled by user
# Note: you may need to restart the kernel to use updated packages.

# %%
import imread
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-d3ef3eba00bc> in <module>
# ----> 1 import imread
#
# ModuleNotFoundError: No module named 'imread'

# %%
import cv2
